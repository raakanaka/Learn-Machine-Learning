# %% [markdown]
# <a href="https://colab.research.google.com/github/rafiqmyura/Learn-Machine-Learning/blob/main/Energy_Sustainable_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests as req
from bs4 import BeautifulSoup as bs
from datetime import datetime
import csv

hades = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36'}

# %%
def scrape_detik(hal):
    global hades
    a = 1
    for page in range(1,hal):
        url = f'https://www.detik.com/search/searchnews?query=energi+terbarukan&sortby=time&page={page}'
        ge = req.get(url,hades).text
        sop = bs(ge,'lxml')
        li = sop.find('div',class_='list media_rows list-berita')
        lin = li.find_all('article')
        for x in lin:
            link = x.find('a')['href']
            date = x.find('a').find('span',class_='date').text.replace('WIB','').replace('detikNews','').split(',')[1]
            headline = x.find('a').find('h2').text
            ge_ = req.get(link,hades).text
            sop_ = bs(ge_,'lxml')
            content = sop_.find_all('div',class_='detail__body-text itp_bodycontent')
            for x in content:
                x = x.find_all('p')
                y  = [y.text for y in x ]
                content_ = ''.join(y).replace('\n', '').replace('ADVERTISEMENT','').replace('SCROLL TO RESUME CONTENT','')
                print(f'done[{a}] > {headline[0:10]}')
                a += 1
                with open('energy.csv','a')as file:
                    wr = csv.writer(file, delimiter=',')
                    wr.writerow([headline,date,link,content_])

# %%
scrape_detik(3)
# Out:
# done[1] > Erick Thoh
# done[2] > Suhu 'Mend
# done[3] > Sinar Mas
# done[4] > Ini 9 Penc
# done[5] > Proyek TPS
# done[6] > PLN Dapat
# done[7] > Baron Tech
# done[8] > Komitmen E
# done[9] > Pertamina
# done[10] > Bank Mandi
# done[11] > Daftar Nam
# done[12] > Siswa Asal
# done[13] > Daftar Ora
# done[14] > Pajak 100
# done[15] > Anies Mau
# done[16] > Ekonomi Hi
# done[17] > Pertama di
# done[18] > Mengenal N

# %%
df = pd.read_csv('/content/energy.csv')
df
# Out:
#    Erick Thohir Bagi-bagi Mobil Listrik ke Pejabat Kementerian BUMN  \
# 0   Suhu 'Mendidih', China Cetak Rekor Terpanas di...
# 1     Sinar Mas Lalui 2023 dengan Semangat Kolaborasi
# 2   Ini 9 Pencapaian Besar Dalam Menyelamatkan Ala...
# 3   Proyek TPST Canggih di Cilacap Nilainya Rp 84 ...
# 4   PLN Dapat Pembiayaan Rp 12 T untuk Program Tra...
# 5   Baron Techno Park, Wisata Edukasi Punya Jam Ma...
# 6   Komitmen Energi Terbarukan Antar Dinas ESDM Ja...
# 7   Pertamina Energy Terminal Kantongi Sertifikat ...
# 8   Bank Mandiri Rajai Kredit Sindikasi, Penyalura...
# 9   Daftar Nama Orang Terkaya yang Pajaknya Mau 'D...
# 10  Siswa Asal Bali Raih Juara di Olimpiade Sains ...
# 11  Daftar Orang Terkaya Indonesia yang Disebut An...
# 12  Pajak 100 Orang Terkaya RI Mau 'Dipelototi' An...
